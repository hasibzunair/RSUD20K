# %%
# Import libraries
import os
import matplotlib.pyplot as plt
from collections import Counter
import seaborn as sns

# Set style
sns.set_theme()
plt.figure(figsize=(7, 3))

# Set the path
path = '../datasets/rsud20k'
train_path = os.path.join(path, 'labels/train')
val_path = os.path.join(path, 'labels/val')
test_path = os.path.join(path, 'labels/test')


labels = []  # Initialize an empty list to store file paths
labels.extend([os.path.join(train_path, label) for label in os.listdir(train_path)])
labels.extend([os.path.join(val_path, label) for label in os.listdir(val_path)])
labels.extend([os.path.join(test_path, label) for label in os.listdir(test_path)])
print(f"Total number of label files: {len(labels)}")

# Get the number of bounding box in each image
ls = []
for file_path in labels:
    try:
        with open(file_path) as file:
            lines_count = sum(1 for line in file)
            ls.append(lines_count)
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        continue

print(f"Total number of lines in all files: {len(ls)}")

# Count the frequency of each number of bounding box
x = Counter(ls)
print(x)

# Plot the distribution
bars = plt.bar(list(x.keys()), list(x.values()), width = 0.9, color='b')  # Convert keys to a list
plt.xticks(range(1, max(x.keys()) + 1))  # Set the xticks to go from 1 to the highest number of bounding box

# Annotate bars with their values
for bar, value in zip(bars, x.values()):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(value),
             ha='center', va='bottom', fontsize=6)


plt.xlabel('Number of Boxes ', fontsize=10)
plt.ylabel('Number of Images', fontsize=10)
# plt.savefig(f'bbox.pdf', format='PDF',bbox_inches='tight')
plt.show()
# Out:
# Total number of label files: 20334
# Total number of lines in all files: 20334
# Counter({5: 2765, 4: 2618, 6: 2352, 3: 2097, 7: 1958, 8: 1494, 2: 1380, 9: 1241, 10: 988, 11: 849, 1: 703, 12: 628, 13: 456, 14: 300, 15: 225, 16: 149, 17: 60, 18: 37, 19: 18, 20: 6, 21: 5, 22: 2, 23: 2, 25: 1})

# %%
# Set the path
path = '../datasets/rsud20k'
train_path = os.path.join(path, 'labels/train')
val_path = os.path.join(path, 'labels/val')
test_path = os.path.join(path, 'labels/test')


labels = []  # Initialize an empty list to store file paths
labels.extend([os.path.join(train_path, label) for label in os.listdir(train_path)])
labels.extend([os.path.join(val_path, label) for label in os.listdir(val_path)])
labels.extend([os.path.join(test_path, label) for label in os.listdir(test_path)])
print(f"Total number of label files: {len(labels)}")

# Get the number of bounding box in each image
ls = []
image_number = []
for file_path in labels:
    try:
        with open(file_path) as file:
            lines_count = sum(1 for line in file)
            ls.append(lines_count)
            if lines_count > 16:
                image_number.append(file_path)
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        continue
print(f"Total number of lines in all files: {len(ls)}")
print(f"Total number of images with more than 16 bounding boxes: {len(image_number)}")
with open('image_number.txt', 'w') as f:
    for item in image_number:
        f.write("%s\n" % item)
    f.close()
print(f"The images are: {image_number}")
# Out:
# Total number of label files: 20334
# Total number of lines in all files: 20334
# Total number of images with more than 16 bounding boxes: 131
# The images are: ['../datasets/bdss20k/labels/train/0000005101.txt', '../datasets/bdss20k/labels/train/0000005553.txt', '../datasets/bdss20k/labels/train/0000005727.txt', '../datasets/bdss20k/labels/train/0000007197.txt', '../datasets/bdss20k/labels/train/0000016429.txt', '../datasets/bdss20k/labels/train/0000009490.txt', '../datasets/bdss20k/labels/train/0000007513.txt', '../datasets/bdss20k/labels/train/0000005909.txt', '../datasets/bdss20k/labels/train/0000016430.txt', '../datasets/bdss20k/labels/train/0000006850.txt', '../datasets/bdss20k/labels/train/0000005838.txt', '../datasets/bdss20k/labels/train/0000009970.txt', '../datasets/bdss20k/labels/train/0000016451.txt', '../datasets/bdss20k/labels/train/0000005099.txt', '../datasets/bdss20k/labels/train/0000009930.txt', '../datasets/bdss20k/labels/train/0000009564.txt', '../datasets/bdss20k/labels/train/0000005575.txt', '../datasets/bdss20k/labels/train/0000010058.txt', '../datasets/bdss20k/labels/train/0000005197.txt', '../datasets/bdss20k/labels/train/0000008817.txt', '../datasets/bdss20k/labels/train/0000002710.txt', '../datasets/bdss20k/labels/train/0000002913.txt', '../datasets/bdss20k/labels/train/0000004915.txt', '../datasets/bdss20k/labels/train/0000016687.txt', '../datasets/bdss20k/labels/train/0000004960.txt', '../datasets/bdss20k/labels/train/0000016367.txt', '../datasets/bdss20k/labels/train/0000002353.txt', '../datasets/bdss20k/labels/train/0000010066.txt', '../datasets/bdss20k/labels/train/0000009065.txt', '../datasets/bdss20k/labels/train/0000005220.txt', '../datasets/bdss20k/labels/train/0000008999.txt', '../datasets/bdss20k/labels/train/0000004963.txt', '../datasets/bdss20k/labels/train/0000005966.txt', '../datasets/bdss20k/labels/train/0000009043.txt', '../datasets/bdss20k/labels/train/0000007497.txt', '../datasets/bdss20k/labels/train/0000005714.txt', '../datasets/bdss20k/labels/train/0000005255.txt', '../datasets/bdss20k/labels/train/0000009637.txt', '../datasets/bdss20k/labels/train/0000016692.txt', '../datasets/bdss20k/labels/train/0000016339.txt', '../datasets/bdss20k/labels/train/0000007431.txt', '../datasets/bdss20k/labels/train/0000016496.txt', '../datasets/bdss20k/labels/train/0000013547.txt', '../datasets/bdss20k/labels/train/0000016500.txt', '../datasets/bdss20k/labels/train/0000004914.txt', '../datasets/bdss20k/labels/train/0000001387.txt', '../datasets/bdss20k/labels/train/0000011150.txt', '../datasets/bdss20k/labels/train/0000005829.txt', '../datasets/bdss20k/labels/train/0000006294.txt', '../datasets/bdss20k/labels/train/0000008926.txt', '../datasets/bdss20k/labels/train/0000002833.txt', '../datasets/bdss20k/labels/train/0000007443.txt', '../datasets/bdss20k/labels/train/0000008900.txt', '../datasets/bdss20k/labels/train/0000010136.txt', '../datasets/bdss20k/labels/train/0000005227.txt', '../datasets/bdss20k/labels/train/0000009889.txt', '../datasets/bdss20k/labels/train/0000009985.txt', '../datasets/bdss20k/labels/train/0000005608.txt', '../datasets/bdss20k/labels/train/0000005685.txt', '../datasets/bdss20k/labels/train/0000005171.txt', '../datasets/bdss20k/labels/train/0000002912.txt', '../datasets/bdss20k/labels/train/0000009002.txt', '../datasets/bdss20k/labels/train/0000005624.txt', '../datasets/bdss20k/labels/train/0000005165.txt', '../datasets/bdss20k/labels/train/0000005207.txt', '../datasets/bdss20k/labels/train/0000016319.txt', '../datasets/bdss20k/labels/train/0000006098.txt', '../datasets/bdss20k/labels/train/0000007071.txt', '../datasets/bdss20k/labels/train/0000016625.txt', '../datasets/bdss20k/labels/train/0000016691.txt', '../datasets/bdss20k/labels/train/0000005248.txt', '../datasets/bdss20k/labels/train/0000005550.txt', '../datasets/bdss20k/labels/train/0000005614.txt', '../datasets/bdss20k/labels/train/0000006685.txt', '../datasets/bdss20k/labels/train/0000011019.txt', '../datasets/bdss20k/labels/train/0000002637.txt', '../datasets/bdss20k/labels/train/0000004985.txt', '../datasets/bdss20k/labels/train/0000016503.txt', '../d ...
